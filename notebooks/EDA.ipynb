# %% [markdown]
# # Life Cycle of Machine Learning Project
#
# Understanding the Problem Statement
#
# Data Collection
#
# Data Check to perform
#
# Exploratory Data Analysis
#
# Data Pre-processing
#
# Model Training
#
# Choose Best model

# %% [markdown]
# # Problem Statement
# Financial threats are displaying a trend about the credit risk of commercial banks as the
# incredible improvement in the financial industry has arisen. In this way, one of the
# biggest threats faces by commercial banks is the risk prediction of credit clients. The
# goal is to predict the probability of credit default based on credit card owner's
# characteristics and payment history.

# %% [markdown]
# # Data Collection
#
# Data Source = https://www.kaggle.com/datasets/uciml/default-of-credit-card-clients-dataset
#
# The data consist of 25 columns and 30k rows

# %% [markdown]
# # 2.1 Import Data and Required Packages
#
# Importing Pandas , Numpy , Matplotlib , Seaborn and Warnings Library.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %% [markdown]
# Import the CSV Data as Pandas Dataframe

# %%
df=pd.read_csv(r"data\UCI_Credit_Card.csv")

# %% [markdown]
# Show Top 5 Records

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %% [markdown]
# Shape of the dataset

# %%
df.shape
# Out:
# (30000, 25)

# %% [markdown]
# # 2.2 Dataset information
#
# ID: ID of each client
#
# LIMIT_BAL: Amount of given credit in NT dollars (includes individual and family/supplementary credit)
#
# SEX: Gender (1=male, 2=female)
#
# EDUCATION: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)
#
# MARRIAGE: Marital status (1=married, 2=single, 3=others)
#
# AGE: Age in years
#
# PAY_0: Repayment status in September, 2005 (-1=pay duly, 1=payment delay for one month, 2=payment delay for two months, … 8=payment delay
# for eight months, 9=payment delay for nine months and above)
#
# PAY_2: Repayment status in August, 2005 (scale same as above)
#
# PAY_3: Repayment status in July, 2005 (scale same as above)
#
# PAY_4: Repayment status in June, 2005 (scale same as above)
#
# PAY_5: Repayment status in May, 2005 (scale same as above)
#
# PAY_6: Repayment status in April, 2005 (scale same as above)
#
# BILL_AMT1: Amount of bill statement in September, 2005 (NT dollar)
#
# BILL_AMT2: Amount of bill statement in August, 2005 (NT dollar)
#
# BILL_AMT3: Amount of bill statement in July, 2005 (NT dollar)
#
# BILL_AMT4: Amount of bill statement in June, 2005 (NT dollar)
#
# BILL_AMT5: Amount of bill statement in May, 2005 (NT dollar)
#
# BILL_AMT6: Amount of bill statement in April, 2005 (NT dollar)
#
# PAY_AMT1: Amount of previous payment in September, 2005 (NT dollar)
#
# PAY_AMT2: Amount of previous payment in August, 2005 (NT dollar)
#
# PAY_AMT3: Amount of previous payment in July, 2005 (NT dollar)
#
# PAY_AMT4: Amount of previous payment in June, 2005 (NT dollar)
#
# PAY_AMT5: Amount of previous payment in May, 2005 (NT dollar)
#
# PAY_AMT6: Amount of previous payment in April, 2005 (NT dollar)
#
# default.payment.next.month: Default payment (1=yes, 0=no)

# %% [markdown]
# # 3 Data Checks to perform
#
# Check Missing values
#
# Check Duplicates
#
# Check data type
#
# Check the number of unique of each column
#
# Check statistics of data set
#
# Check various categories present in the different categorical column

# %% [markdown]
# # 3.1 Chack Missing Values

# %%
df.isna().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %% [markdown]
# There is no missing  values in the data set

# %% [markdown]
# # 3.2 Check Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicates values in the data set

# %% [markdown]
# # 3.3 Check data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %% [markdown]
# There are no categorical columns

# %% [markdown]
# # 3.4 Checking the number of unique values of each column

# %%
df.nunique()
# Out:
# ID                            30000
# LIMIT_BAL                        81
# SEX                               2
# EDUCATION                         7
# MARRIAGE                          4
# AGE                              56
# PAY_0                            11
# PAY_2                            11
# PAY_3                            11
# PAY_4                            11
# PAY_5                            10
# PAY_6                            10
# BILL_AMT1                     22723
# BILL_AMT2                     22346
# BILL_AMT3                     22026
# BILL_AMT4                     21548
# BILL_AMT5                     21010
# BILL_AMT6                     20604
# PAY_AMT1                       7943
# PAY_AMT2                       7899
# PAY_AMT3                       7518
# PAY_AMT4                       6937
# PAY_AMT5                       6897
# PAY_AMT6                       6939
# default.payment.next.month        2
# dtype: int64

# %% [markdown]
# # 3.5 Check Statistics of dataset

# %%
df.describe().T
# Out:
#                               count           mean            std       min  \
# ID                          30000.0   15000.500000    8660.398374       1.0
# LIMIT_BAL                   30000.0  167484.322667  129747.661567   10000.0
# SEX                         30000.0       1.603733       0.489129       1.0
# EDUCATION                   30000.0       1.853133       0.790349       0.0
# MARRIAGE                    30000.0       1.551867       0.521970       0.0
# AGE                         30000.0      35.485500       9.217904      21.0
# PAY_0                       30000.0      -0.016700       1.123802      -2.0
# PAY_2                       30000.0      -0.133767       1.197186      -2.0
# PAY_3                       30000.0      -0.166200       1.196868      -2.0
# PAY_4                       30000.0      -0.220667       1.169139      -2.0
# PAY_5                       30000.0      -0.266200       1.133187      -2.0
# ...

# %% [markdown]
# ##### Insight
#
# 1. From above decription of numerical data ,all means and std are not close close to each other

# %% [markdown]
# # Exploring Data

# %%
# define numerical and categorical columns 
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns

print("We have {} numerical features : {}".format(len(numeric_features),numeric_features))
print("We have {} categorical features : {}".format(len(categorical_features),categorical_features))
# Out:
# We have 25 numerical features : ['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default.payment.next.month']
# We have 0 categorical features : []

# %% [markdown]
# # 4 Exploring Data (Visualization)

# %% [markdown]
# ##### 4.1 Visualize AGE and Default payment next month
#
# Hitogram
#
# Kernel Distribution Funtion(KDE )

# %%
fig,axs = plt.subplots(1,2,figsize=(15,7))
plt.subplot(121)
sns.histplot(data=df , x='default.payment.next.month' , bins=30 , kde=True, color='g' )
plt.subplot(122)
sns.histplot(data=df , x="default.payment.next.month" , kde=True , hue= 'SEX')
# Out:
# <Axes: xlabel='default.payment.next.month', ylabel='Count'>

# %% [markdown]
# #### Insights
#
# The most default payment next month people are females

# %%
sns.countplot(df,x='default.payment.next.month',hue='SEX')
# Out:
# <Axes: xlabel='default.payment.next.month', ylabel='count'>

# %% [markdown]
# #### Insights
# The credit card holders  most of them are females

# %%
sns.countplot(df,x='default.payment.next.month',hue='MARRIAGE')
# Out:
# <Axes: xlabel='default.payment.next.month', ylabel='count'>

# %% [markdown]
# ### insights
# The single people are pay their bill on time than married people

# %%
sns.countplot(df,x='default.payment.next.month',hue='AGE')
# Out:
# <Axes: xlabel='default.payment.next.month', ylabel='count'>

# %% [markdown]
# ##### Insights
# People  between 21 to 45 have their default payment next month

# %%
sns.countplot(df,x='default.payment.next.month',hue='EDUCATION')
# Out:
# <Axes: xlabel='default.payment.next.month', ylabel='count'>

# %% [markdown]
# ### Insights
#
# The most graduate school and university graduate people are use credit card
#
# The people have their default payment next month are graduate school and in university or university graduates

# %% [markdown]
# # Univariate Analysis using pieplot

# %%
plt.rcParams['figure.figsize'] = (30,12)

plt.subplot(1,5,1)
size = df['SEX'].value_counts()
labels = 'Female','Male'
color = ['red' , 'green','yellow']

plt.pie(size, colors= color , labels=labels , autopct='.%2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1bee1287040>,
# ...
#  [Text(-0.3521651536748663, 1.042103499915991, 'Female'),
#   Text(0.35216525124363574, -1.0421034669439053, 'Male')],
#  [Text(-0.1920900838226543, 0.5684200908632677, '.60.373336%'),
#   Text(0.1920901370419831, -0.5684200728784937, '.39.626667%')])

# %%
sns.countplot(df,x='MARRIAGE',hue='SEX')
# Out:
# <Axes: xlabel='MARRIAGE', ylabel='count'>

# %% [markdown]
# ### Insites
#
# Most of the cardholder are married

# %% [markdown]
# # Plot a pair so as to see any relation between variables

# %%
plt.close()
sns.set_style('whitegrid')
z = sns.pairplot(df[['LIMIT_BAL','SEX',"EDUCATION",'MARRIAGE','AGE','default.payment.next.month']],hue='default.payment.next.month',height=6)

z.fig.suptitle('Pair plot of all features',fontsize=25)
# Out:
# Text(0.5, 0.98, 'Pair plot of all features')

# %%
sns.set_style('darkgrid')
sns.FacetGrid(df,hue='default.payment.next.month',height=20,aspect=1).map(plt.scatter,'LIMIT_BAL','AGE')

plt.ylabel('AGE')
plt.xlabel('LIMIT_BAL')
plt.legend()
plt.title('2D scatter plt of AGE V/s LIMIT_BAL')
# Out:
# Text(0.5, 1.0, '2D scatter plt of AGE V/s LIMIT_BAL')

# %% [markdown]
# ### Insights
#
# From the above plat can we see that people having higher amount of credit are defaulting less

# %%
sns.displot(df['AGE'])
plt.title('Distribution of age ')
# Out:
# Text(0.5, 1.0, 'Distribution of age ')

# %% [markdown]
# ### insight
# we can see that most of the people are in late 20's and 30's

# %%
df.loc[df['SEX']==1,'default.payment.next.month'].value_counts()
# Out:
# 0    9015
# 1    2873
# Name: default.payment.next.month, dtype: int64

# %% [markdown]
# Ratio
# 2873/9015 = 0.3186

# %%
df.loc[df['SEX']==2,'default.payment.next.month'].value_counts()
# Out:
# 0    14349
# 1     3763
# Name: default.payment.next.month, dtype: int64

# %% [markdown]
# Ratio
# 3763/14349 = 0.262

# %% [markdown]
# ### Insights
# we can see that from the ratio that female have less percentage of defaults as compared to males

# %% [markdown]
# # Bivariate Analysis (Is education has any impact on defaults payment next month)

# %%
df.groupby('default.payment.next.month').agg('mean').plot(kind='barh',figsize=(10,10))
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)

# %% [markdown]
# # Outlier Detection and Removal approches
#
# Identifying outliers with visualization
#
# Z-score method
#
# Interquartile Range Method(IQR) method
#
# Compare Skewness

# %% [markdown]
# # Importing Data and Requied Packages
#
# Importing Pandas ,Numpy , Matplotlib ,Seaborn , Warnings Library

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.stats as stats
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing Data

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %% [markdown]
# # 1. Identifying outliers with visualization

# %%
num_features=[col for col in df.columns if df[col].dtype!='O']
num_df=df[num_features]
num_df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
plt.figure(figsize=(22,18))
for i,col in enumerate(num_df.columns):
    plt.subplot(4,9,i+1)
    sns.boxplot(num_df[col])

# %%
plt.figure(figsize=(15,10))
plt.suptitle('Ditsribution of numeric feature ',fontsize=20,fontweight='bold',alpha=0.8,y=1.)
numeric_features = [feature for feature in df.columns if df[feature].dtype!='o']
for i in range(0,len(numeric_features)):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x=df[numeric_features[i]],color='blue')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\LENOVO\Desktop\Python\py.py\Full_Stack_Data_Science\Ineuron_internships\Credit_Card_Default_Prediction\notebooks\EDA.ipynb Cell 67 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/LENOVO/Desktop/Python/py.py/Full_Stack_Data_Science/Ineuron_internships/Credit_Card_Default_Prediction/notebooks/EDA.ipynb#Y124sZmlsZQ%3D%3D?line=2'>3</a> numeric_features = [feature for feature in df.columns if df[feature].dtype!='o']
#       <a href='vscode-notebook-cell:/c%3A/Users/LENOVO/Desktop/Python/py.py/Full_Stack_Data_Science/Ineuron_internships/Credit_Card_Default_Prediction/notebooks/EDA.ipynb#Y124sZmlsZQ%3D%3D?line=3'>4</a> for i in range(0,len(numeric_features)):
# ...

# %% [markdown]
# #### Insights
#
# The outliers are there , as there are many data points which lie far away from maximum points

# %%
sns.boxplot(x='default.payment.next.month',y='LIMIT_BAL',data=df)
plt.ylabel('LIMIT_BAL')
plt.xlabel('default.payment.next.month')
plt.title('Boxplot for the default.payment.next.month V/s LIMIT_BAL ')
# Out:
# Text(0.5, 1.0, 'Boxplot for the default.payment.next.month V/s LIMIT_BAL ')

# %%
sns.boxplot(df['LIMIT_BAL'])
plt.title('Limit Balance before Outlier Treatment')
# Out:
# Text(0.5, 1.0, 'Limit Balance before Outlier Treatment')

# %% [markdown]
# # Let's check correlation matrix to check multicolierarity between features

# %%
corr_matrix=df.corr()
plt.figure(figsize=(20,12))
sns.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Insights
# From the above correaltion matrix we can clearly see that PAY_0 to PAY_6 , the repayment status of months which are nearly have much higher correlation than others, similarly for amount of bill statement

# %%
print(df.hist(bins=30,figsize=(20,20),color='r'))
# Out:
# [[<Axes: title={'center': 'ID'}> <Axes: title={'center': 'LIMIT_BAL'}>
#   <Axes: title={'center': 'SEX'}> <Axes: title={'center': 'EDUCATION'}>
#   <Axes: title={'center': 'MARRIAGE'}>]
#  [<Axes: title={'center': 'AGE'}> <Axes: title={'center': 'PAY_0'}>
#   <Axes: title={'center': 'PAY_2'}> <Axes: title={'center': 'PAY_3'}>
#   <Axes: title={'center': 'PAY_4'}>]
#  [<Axes: title={'center': 'PAY_5'}> <Axes: title={'center': 'PAY_6'}>
#   <Axes: title={'center': 'BILL_AMT1'}>
#   <Axes: title={'center': 'BILL_AMT2'}>
#   <Axes: title={'center': 'BILL_AMT3'}>]
#  [<Axes: title={'center': 'BILL_AMT4'}>
#   <Axes: title={'center': 'BILL_AMT5'}>
#   <Axes: title={'center': 'BILL_AMT6'}>
#   <Axes: title={'center': 'PAY_AMT1'}>
#   <Axes: title={'center': 'PAY_AMT2'}>]
#  [<Axes: title={'center': 'PAY_AMT3'}>
#   <Axes: title={'center': 'PAY_AMT4'}>
#   <Axes: title={'center': 'PAY_AMT5'}>
#   <Axes: title={'center': 'PAY_AMT6'}>
# ...

# %% [markdown]
# ### Insights
#
# We can clearly see that the distribution of the data follows power law , which means that general standardization techniques won't be helpful beacause they assume the data to be gaussian
#
# We can apply Median Absolute Deviation (MAD) Scaling which is robust to outliers
